# %% [markdown]
# # Hi This is the heading for my quantum notebook
# More text in here that would later describe the contnents of this notebook. For the time being here's a list of the things you can do:
#
# 1. you can make things **bold**
# 2. you can links (link to {google})(https://google.com)
# 3. here's a link to [learn python] (https://realpython.com)

# %%
2+2
# Out:
# 4

# %%
import qiskit

# %%
c1=3+4j
c2=5+6j
c3=c1+c2

# %%
print(c3)
# Out:
# (8+10j)

# %% [markdown]
# # Section 2
# Presenting more features of python, matplotlib and many other things

# %%
import math
import numpy as np

a=np.linspace(0,2+math.pi,20)
b=np.sin(a)

# %%
import matplotlib.pyplot as plt
plt.plot(a,b)

# %%
ghp_cf4vyzzlqUI190fL9NSV9jHKrFIxJH43Cx4
https://github.com/qBraid/NCAT-QISE-Courses.git
